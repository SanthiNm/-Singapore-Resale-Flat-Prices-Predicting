# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("B:\Project\.venv\singapore_data\ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")
df2 = pd.read_csv("B:\Project\.venv\singapore_data\ResaleFlatPricesBasedonApprovalDate19901999.csv")
df3 = pd.read_csv("B:\Project\.venv\singapore_data\ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")
df4 = pd.read_csv("B:\Project\.venv\singapore_data\ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")
df5 = pd.read_csv("B:\Project\.venv\singapore_data\ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")

# %%
#Merging all the dataframes
df = pd.concat([df1, df2, df3, df4, df5])

# %%
#saving the data
df.to_csv('ResaleFlatPrices.csv', index=False)

# %%
house = pd.read_csv("B:\Project\.venv\ResaleFlatPrices.csv",low_memory=False)

# %%
house
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       2000-01  ANG MO KIO     3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1       2000-01  ANG MO KIO     3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2       2000-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3       2000-01  ANG MO KIO     3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4       2000-01  ANG MO KIO     3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
# ...         ...         ...        ...   ...               ...          ...
# 932367  2014-12      YISHUN     5 ROOM   816      YISHUN ST 81     10 TO 12
# 932368  2014-12      YISHUN  EXECUTIVE   325       YISHUN CTRL     10 TO 12
# 932369  2014-12      YISHUN  EXECUTIVE   618    YISHUN RING RD     07 TO 09
# 932370  2014-12      YISHUN  EXECUTIVE   277      YISHUN ST 22     07 TO 09
# 932371  2014-12      YISHUN  EXECUTIVE   277      YISHUN ST 22     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 69.0        Improved                 1986      147000.0
# 1                 61.0        Improved                 1986      144000.0
# 2                 73.0  New Generation                 1976      159000.0
# 3                 73.0  New Generation                 1976      167000.0
# 4                 67.0  New Generation                 1976      163000.0
# ...                ...             ...                  ...           ...
# 932367           122.0        Improved                 1988      580000.0
# 932368           146.0      Maisonette                 1988      540000.0
# 932369           164.0       Apartment                 1992      738000.0
# 932370           152.0      Maisonette                 1985      592000.0
# 932371           146.0      Maisonette                 1985      545000.0
#
#        remaining_lease
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 932367             NaN
# 932368             NaN
# 932369             NaN
# 932370             NaN
# 932371             NaN
#
# [932372 rows x 11 columns]

# %%
#This will process the file in chunks and assign the data type based on the entire column rather than a small sample. This approach reduces memory usage but might be slower.

# %%
house
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       2000-01  ANG MO KIO     3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1       2000-01  ANG MO KIO     3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2       2000-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3       2000-01  ANG MO KIO     3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4       2000-01  ANG MO KIO     3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
# ...         ...         ...        ...   ...               ...          ...
# 932367  2014-12      YISHUN     5 ROOM   816      YISHUN ST 81     10 TO 12
# 932368  2014-12      YISHUN  EXECUTIVE   325       YISHUN CTRL     10 TO 12
# 932369  2014-12      YISHUN  EXECUTIVE   618    YISHUN RING RD     07 TO 09
# 932370  2014-12      YISHUN  EXECUTIVE   277      YISHUN ST 22     07 TO 09
# 932371  2014-12      YISHUN  EXECUTIVE   277      YISHUN ST 22     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 69.0        Improved                 1986      147000.0
# 1                 61.0        Improved                 1986      144000.0
# 2                 73.0  New Generation                 1976      159000.0
# 3                 73.0  New Generation                 1976      167000.0
# 4                 67.0  New Generation                 1976      163000.0
# ...                ...             ...                  ...           ...
# 932367           122.0        Improved                 1988      580000.0
# 932368           146.0      Maisonette                 1988      540000.0
# 932369           164.0       Apartment                 1992      738000.0
# 932370           152.0      Maisonette                 1985      592000.0
# 932371           146.0      Maisonette                 1985      545000.0
#
#        remaining_lease
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 932367             NaN
# 932368             NaN
# 932369             NaN
# 932370             NaN
# 932371             NaN
#
# [932372 rows x 11 columns]

# %%
# checking dataset shape
house.shape
# Out:
# (932372, 11)

# %%
# checking the datatypes
house.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# dtype: object

# %%
# checking the null values in dataset
house.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %%
#fill the null values suing ML models
house = house.fillna(0)

# %%
# checking the null values in dataset
house.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# dtype: int64

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932372 entries, 0 to 932371
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                932372 non-null  object
#  1   town                 932372 non-null  object
#  2   flat_type            932372 non-null  object
#  3   block                932372 non-null  object
#  4   street_name          932372 non-null  object
#  5   storey_range         932372 non-null  object
#  6   floor_area_sqm       932372 non-null  float64
#  7   flat_model           932372 non-null  object
#  8   lease_commence_date  932372 non-null  int64
#  9   resale_price         932372 non-null  float64
#  10  remaining_lease      932372 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 78.2+ MB

# %%
#descriptive statistics analaysis

house.describe().T
# Out:
#                         count           mean            std     min       25%  \
# floor_area_sqm       932372.0      95.687326      25.816280    28.0      73.0
# lease_commence_date  932372.0    1988.331706      10.719523  1966.0    1981.0
# resale_price         932372.0  322407.117832  171986.419522  5000.0  194000.0
#
#                           50%       75%        max
# floor_area_sqm           93.0     113.0      366.7
# lease_commence_date    1986.0    1996.0     2020.0
# resale_price         299000.0  420000.0  1588000.0

# %%
# checking the unique values in flat_type feature
house['flat_type'].value_counts()
# Out:
# flat_type
# 4 ROOM              354644
# 3 ROOM              297243
# 5 ROOM              196652
# EXECUTIVE            69988
# 2 ROOM               11996
# 1 ROOM                1305
# MULTI GENERATION       279
# MULTI-GENERATION       265
# Name: count, dtype: int64

# %%
# checking the unique values in town feature
house['town'].value_counts()
# Out:
# town
# TAMPINES           80336
# YISHUN             70415
# JURONG WEST        67060
# BEDOK              66916
# WOODLANDS          65909
# ANG MO KIO         52300
# HOUGANG            51008
# BUKIT BATOK        44755
# CHOA CHU KANG      38573
# BUKIT MERAH        34560
# PASIR RIS          33345
# SENGKANG           32868
# TOA PAYOH          31699
# QUEENSTOWN         28910
# GEYLANG            28321
# CLEMENTI           28152
# BUKIT PANJANG      27845
# KALLANG/WHAMPOA    27374
# JURONG EAST        24884
# SERANGOON          22914
# BISHAN             21349
# PUNGGOL            21038
# SEMBAWANG          14002
# MARINE PARADE       8062
# CENTRAL AREA        7184
# BUKIT TIMAH         2529
# LIM CHU KANG          64
# Name: count, dtype: int64

# %%
house['storey_range'].value_counts()
# Out:
# storey_range
# 04 TO 06    233821
# 07 TO 09    211265
# 01 TO 03    187346
# 10 TO 12    179787
# 13 TO 15     62540
# 16 TO 18     24416
# 19 TO 21     11549
# 22 TO 24      7508
# 25 TO 27      3489
# 01 TO 05      2700
# 06 TO 10      2474
# 28 TO 30      1672
# 11 TO 15      1259
# 31 TO 33       646
# 34 TO 36       592
# 37 TO 39       518
# 16 TO 20       265
# 40 TO 42       249
# 21 TO 25        92
# 43 TO 45        66
# 46 TO 48        53
# 26 TO 30        39
# 49 TO 51        17
# 36 TO 40         7
# 31 TO 35         2
# Name: count, dtype: int64

# %%
house['flat_model'].value_counts()
# Out:
# flat_model
# Model A                   196835
# Improved                  169474
# New Generation            110706
# NEW GENERATION             78898
# IMPROVED                   73589
# MODEL A                    70381
# Premium Apartment          47329
# Simplified                 34481
# Apartment                  25745
# Standard                   25285
# SIMPLIFIED                 23258
# Maisonette                 17578
# STANDARD                   17375
# MAISONETTE                 12215
# Model A2                   10199
# APARTMENT                   9901
# DBSS                        3359
# Adjoined flat               1259
# Model A-Maisonette          1099
# MODEL A-MAISONETTE           982
# Terrace                      448
# Type S1                      442
# MULTI GENERATION             279
# Multi Generation             265
# TERRACE                      247
# Type S2                      217
# 2-room                       136
# Premium Apartment Loft       112
# Premium Maisonette            86
# Improved-Maisonette           83
# IMPROVED-MAISONETTE           44
# 3Gen                          38
# 2-ROOM                        21
# PREMIUM APARTMENT              6
# Name: count, dtype: int64

# %%
house.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'remaining_lease'],
#       dtype='object')

# %%
# Convert the 'month' column to a datetime format
house['month'] = pd.to_datetime(house['month'])

# Extract the year and month into separate columns
house['year'] = house['month'].dt.year
house['month_of_year'] = house['month'].dt.month
house
# Out:
#             month        town  flat_type block       street_name storey_range  \
# 0      2000-01-01  ANG MO KIO     3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1      2000-01-01  ANG MO KIO     3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2      2000-01-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3      2000-01-01  ANG MO KIO     3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4      2000-01-01  ANG MO KIO     3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
# ...           ...         ...        ...   ...               ...          ...
# 932367 2014-12-01      YISHUN     5 ROOM   816      YISHUN ST 81     10 TO 12
# 932368 2014-12-01      YISHUN  EXECUTIVE   325       YISHUN CTRL     10 TO 12
# 932369 2014-12-01      YISHUN  EXECUTIVE   618    YISHUN RING RD     07 TO 09
# 932370 2014-12-01      YISHUN  EXECUTIVE   277      YISHUN ST 22     07 TO 09
# 932371 2014-12-01      YISHUN  EXECUTIVE   277      YISHUN ST 22     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 69.0        Improved                 1986      147000.0
# 1                 61.0        Improved                 1986      144000.0
# 2                 73.0  New Generation                 1976      159000.0
# 3                 73.0  New Generation                 1976      167000.0
# 4                 67.0  New Generation                 1976      163000.0
# ...                ...             ...                  ...           ...
# 932367           122.0        Improved                 1988      580000.0
# 932368           146.0      Maisonette                 1988      540000.0
# 932369           164.0       Apartment                 1992      738000.0
# 932370           152.0      Maisonette                 1985      592000.0
# 932371           146.0      Maisonette                 1985      545000.0
#
#        remaining_lease  year  month_of_year
# 0                    0  2000              1
# 1                    0  2000              1
# 2                    0  2000              1
# 3                    0  2000              1
# 4                    0  2000              1
# ...                ...   ...            ...
# 932367               0  2014             12
# 932368               0  2014             12
# 932369               0  2014             12
# 932370               0  2014             12
# 932371               0  2014             12
#
# [932372 rows x 13 columns]

# %%
house.dtypes
# Out:
# month                  datetime64[ns]
# town                           object
# flat_type                      object
# block                          object
# street_name                    object
# storey_range                   object
# floor_area_sqm                float64
# flat_model                     object
# lease_commence_date             int64
# resale_price                  float64
# remaining_lease                object
# year                            int32
# month_of_year                   int32
# dtype: object

# %%
house['lease_commence_year'] = pd.to_datetime(house['lease_commence_date'],format = '%Y').dt.year
# Extract the year of lease commencement
#house['lease_commence_year'] = house['lease_commence_date'].dt.year

# %%
house
# Out:
#             month        town  flat_type block       street_name storey_range  \
# 0      2000-01-01  ANG MO KIO     3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1      2000-01-01  ANG MO KIO     3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2      2000-01-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3      2000-01-01  ANG MO KIO     3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4      2000-01-01  ANG MO KIO     3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
# ...           ...         ...        ...   ...               ...          ...
# 932367 2014-12-01      YISHUN     5 ROOM   816      YISHUN ST 81     10 TO 12
# 932368 2014-12-01      YISHUN  EXECUTIVE   325       YISHUN CTRL     10 TO 12
# 932369 2014-12-01      YISHUN  EXECUTIVE   618    YISHUN RING RD     07 TO 09
# 932370 2014-12-01      YISHUN  EXECUTIVE   277      YISHUN ST 22     07 TO 09
# 932371 2014-12-01      YISHUN  EXECUTIVE   277      YISHUN ST 22     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 69.0        Improved                 1986      147000.0
# 1                 61.0        Improved                 1986      144000.0
# 2                 73.0  New Generation                 1976      159000.0
# 3                 73.0  New Generation                 1976      167000.0
# 4                 67.0  New Generation                 1976      163000.0
# ...                ...             ...                  ...           ...
# 932367           122.0        Improved                 1988      580000.0
# 932368           146.0      Maisonette                 1988      540000.0
# 932369           164.0       Apartment                 1992      738000.0
# 932370           152.0      Maisonette                 1985      592000.0
# 932371           146.0      Maisonette                 1985      545000.0
#
#        remaining_lease  year  month_of_year  lease_commence_year
# 0                    0  2000              1                 1986
# 1                    0  2000              1                 1986
# 2                    0  2000              1                 1976
# 3                    0  2000              1                 1976
# 4                    0  2000              1                 1976
# ...                ...   ...            ...                  ...
# 932367               0  2014             12                 1988
# 932368               0  2014             12                 1988
# 932369               0  2014             12                 1992
# 932370               0  2014             12                 1985
# 932371               0  2014             12                 1985
#
# [932372 rows x 14 columns]

# %%
house.dtypes
# Out:
# month                  datetime64[ns]
# town                           object
# flat_type                      object
# block                          object
# street_name                    object
# storey_range                   object
# floor_area_sqm                float64
# flat_model                     object
# lease_commence_date             int64
# resale_price                  float64
# remaining_lease                object
# year                            int32
# month_of_year                   int32
# lease_commence_year             int32
# dtype: object

# %%
# Extract the remaining_lease feature

data = house['remaining_lease']
house_new = pd.DataFrame(data)

# Extract years and months using regular expressions
lease_info = house['remaining_lease'].str.extract(r'(\d+) years (\d+) months')
lease_info.columns = ['years', 'months']

# Convert to numeric values
house['remaining_lease_years'] = pd.to_numeric(lease_info['years'])
house['remaining_lease_months'] = pd.to_numeric(lease_info['months'])

# %%
house_new_data = house.copy()

# %%
house_new_data
# Out:
#             month        town  flat_type block       street_name storey_range  \
# 0      2000-01-01  ANG MO KIO     3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1      2000-01-01  ANG MO KIO     3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2      2000-01-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3      2000-01-01  ANG MO KIO     3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4      2000-01-01  ANG MO KIO     3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
# ...           ...         ...        ...   ...               ...          ...
# 932367 2014-12-01      YISHUN     5 ROOM   816      YISHUN ST 81     10 TO 12
# 932368 2014-12-01      YISHUN  EXECUTIVE   325       YISHUN CTRL     10 TO 12
# 932369 2014-12-01      YISHUN  EXECUTIVE   618    YISHUN RING RD     07 TO 09
# 932370 2014-12-01      YISHUN  EXECUTIVE   277      YISHUN ST 22     07 TO 09
# 932371 2014-12-01      YISHUN  EXECUTIVE   277      YISHUN ST 22     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0                 69.0        Improved                 1986      147000.0
# 1                 61.0        Improved                 1986      144000.0
# 2                 73.0  New Generation                 1976      159000.0
# 3                 73.0  New Generation                 1976      167000.0
# 4                 67.0  New Generation                 1976      163000.0
# ...                ...             ...                  ...           ...
# 932367           122.0        Improved                 1988      580000.0
# 932368           146.0      Maisonette                 1988      540000.0
# 932369           164.0       Apartment                 1992      738000.0
# 932370           152.0      Maisonette                 1985      592000.0
# 932371           146.0      Maisonette                 1985      545000.0
#
#        remaining_lease  year  month_of_year  lease_commence_year  \
# 0                    0  2000              1                 1986
# 1                    0  2000              1                 1986
# 2                    0  2000              1                 1976
# 3                    0  2000              1                 1976
# 4                    0  2000              1                 1976
# ...                ...   ...            ...                  ...
# 932367               0  2014             12                 1988
# 932368               0  2014             12                 1988
# 932369               0  2014             12                 1992
# 932370               0  2014             12                 1985
# 932371               0  2014             12                 1985
#
#         remaining_lease_years  remaining_lease_months
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# ...                       ...                     ...
# 932367                    NaN                     NaN
# 932368                    NaN                     NaN
# 932369                    NaN                     NaN
# 932370                    NaN                     NaN
# 932371                    NaN                     NaN
#
# [932372 rows x 16 columns]

# %%
house_new_data.isnull().sum()
# Out:
# month                          0
# town                           0
# flat_type                      0
# block                          0
# street_name                    0
# storey_range                   0
# floor_area_sqm                 0
# flat_model                     0
# lease_commence_date            0
# resale_price                   0
# remaining_lease                0
# year                           0
# month_of_year                  0
# lease_commence_year            0
# remaining_lease_years     776729
# remaining_lease_months    776729
# dtype: int64

# %%
# handleing the null values using mean method
house_new_data['remaining_lease_years'].fillna(house['remaining_lease_years'].mean(),inplace = True)
house_new_data['remaining_lease_months'].fillna(house['remaining_lease_months'].mean(),inplace = True)
house_new_data.isnull().sum()
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_18260\1077114996.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house_new_data['remaining_lease_years'].fillna(house['remaining_lease_years'].mean(),inplace = True)
# C:\Users\santh\AppData\Local\Temp\ipykernel_18260\1077114996.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house_new_data['remaining_lease_months'].fillna(house['remaining_lease_months'].mean(),inplace = True)
# month                     0
# town                      0
# flat_type                 0
# block                     0
# street_name               0
# storey_range              0
# floor_area_sqm            0
# flat_model                0
# lease_commence_date       0
# resale_price              0
# remaining_lease           0
# year                      0
# month_of_year             0
# lease_commence_year       0
# remaining_lease_years     0
# remaining_lease_months    0
# dtype: int64

# %%
house_new_data.drop(columns=['month','lease_commence_date','remaining_lease'],inplace = True)

# %%
house_new_data
# Out:
#               town  flat_type block       street_name storey_range  \
# 0       ANG MO KIO     3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1       ANG MO KIO     3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2       ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3       ANG MO KIO     3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4       ANG MO KIO     3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
# ...            ...        ...   ...               ...          ...
# 932367      YISHUN     5 ROOM   816      YISHUN ST 81     10 TO 12
# 932368      YISHUN  EXECUTIVE   325       YISHUN CTRL     10 TO 12
# 932369      YISHUN  EXECUTIVE   618    YISHUN RING RD     07 TO 09
# 932370      YISHUN  EXECUTIVE   277      YISHUN ST 22     07 TO 09
# 932371      YISHUN  EXECUTIVE   277      YISHUN ST 22     04 TO 06
#
#         floor_area_sqm      flat_model  resale_price  year  month_of_year  \
# 0                 69.0        Improved      147000.0  2000              1
# 1                 61.0        Improved      144000.0  2000              1
# 2                 73.0  New Generation      159000.0  2000              1
# 3                 73.0  New Generation      167000.0  2000              1
# 4                 67.0  New Generation      163000.0  2000              1
# ...                ...             ...           ...   ...            ...
# 932367           122.0        Improved      580000.0  2014             12
# 932368           146.0      Maisonette      540000.0  2014             12
# 932369           164.0       Apartment      738000.0  2014             12
# 932370           152.0      Maisonette      592000.0  2014             12
# 932371           146.0      Maisonette      545000.0  2014             12
#
#         lease_commence_year  remaining_lease_years  remaining_lease_months
# 0                      1986              74.007684                6.535533
# 1                      1986              74.007684                6.535533
# 2                      1976              74.007684                6.535533
# 3                      1976              74.007684                6.535533
# 4                      1976              74.007684                6.535533
# ...                     ...                    ...                     ...
# 932367                 1988              74.007684                6.535533
# 932368                 1988              74.007684                6.535533
# 932369                 1992              74.007684                6.535533
# 932370                 1985              74.007684                6.535533
# 932371                 1985              74.007684                6.535533
#
# [932372 rows x 13 columns]

# %% [markdown]
# DATA PREPROCESSING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
house_new_data['town'] = encoder.fit_transform(house_new_data['town'])
house_new_data['flat_type'] = encoder.fit_transform(house_new_data['flat_type'])
house_new_data['storey_range'] = encoder.fit_transform(house_new_data['storey_range'])
house_new_data['flat_model'] = encoder.fit_transform(house_new_data['flat_model'])

# %%
house_new_data
# Out:
#         town  flat_type block       street_name  storey_range  floor_area_sqm  \
# 0          0          2   170  ANG MO KIO AVE 4             4            69.0
# 1          0          2   174  ANG MO KIO AVE 4             2            61.0
# 2          0          2   216  ANG MO KIO AVE 1             4            73.0
# 3          0          2   215  ANG MO KIO AVE 1             4            73.0
# 4          0          2   218  ANG MO KIO AVE 1             4            67.0
# ...      ...        ...   ...               ...           ...             ...
# 932367    26          4   816      YISHUN ST 81             5           122.0
# 932368    26          5   325       YISHUN CTRL             5           146.0
# 932369    26          5   618    YISHUN RING RD             4           164.0
# 932370    26          5   277      YISHUN ST 22             4           152.0
# 932371    26          5   277      YISHUN ST 22             2           146.0
#
#         flat_model  resale_price  year  month_of_year  lease_commence_year  \
# 0                9      147000.0  2000              1                 1986
# 1                9      144000.0  2000              1                 1986
# 2               21      159000.0  2000              1                 1976
# 3               21      167000.0  2000              1                 1976
# 4               21      163000.0  2000              1                 1976
# ...            ...           ...   ...            ...                  ...
# 932367           9      580000.0  2014             12                 1988
# 932368          15      540000.0  2014             12                 1988
# 932369           5      738000.0  2014             12                 1992
# 932370          15      592000.0  2014             12                 1985
# 932371          15      545000.0  2014             12                 1985
#
#         remaining_lease_years  remaining_lease_months
# 0                   74.007684                6.535533
# 1                   74.007684                6.535533
# 2                   74.007684                6.535533
# 3                   74.007684                6.535533
# 4                   74.007684                6.535533
# ...                       ...                     ...
# 932367              74.007684                6.535533
# 932368              74.007684                6.535533
# 932369              74.007684                6.535533
# 932370              74.007684                6.535533
# 932371              74.007684                6.535533
#
# [932372 rows x 13 columns]

# %%
# after encoding descriptive statistics analaysis

house_new_data.describe().T
# Out:
#                            count           mean            std     min  \
# town                    932372.0      13.656423       8.793760     0.0
# flat_type               932372.0       3.014345       0.949249     0.0
# storey_range            932372.0       3.413030       2.667791     0.0
# floor_area_sqm          932372.0      95.687326      25.816280    28.0
# flat_model              932372.0      15.715650       6.663780     0.0
# resale_price            932372.0  322407.117832  171986.419522  5000.0
# year                    932372.0    2006.268208       9.389209  1990.0
# month_of_year           932372.0       6.551181       3.404236     1.0
# lease_commence_year     932372.0    1988.331706      10.719523  1966.0
# remaining_lease_years   932372.0      74.007684       5.704605    41.0
# remaining_lease_months  932372.0       6.535533       1.179759     0.0
#
#                                   25%            50%            75%        max
# town                         5.000000      13.000000      23.000000       26.0
# flat_type                    2.000000       3.000000       4.000000        7.0
# storey_range                 2.000000       4.000000       5.000000       24.0
# floor_area_sqm              73.000000      93.000000     113.000000      366.7
# flat_model                   9.000000      16.000000      21.000000       33.0
# resale_price            194000.000000  299000.000000  420000.000000  1588000.0
# year                      1999.000000    2005.000000    2014.000000     2024.0
# month_of_year                4.000000       7.000000      10.000000       12.0
# lease_commence_year       1981.000000    1986.000000    1996.000000     2020.0
# remaining_lease_years       74.007684      74.007684      74.007684       97.0
# remaining_lease_months       6.535533       6.535533       6.535533       11.0

# %% [markdown]
# Skewness Handling

# %%
# checking the outliars using boxplot distribution plot

def plot(house_new_data,column):
    sns.histplot(data = house_new_data ,x = column,kde = True ,bins = 40,color = 'salmon')
    plt.title(f'distribution  plot for {column}')
    plt.show()

# %%
for i in ['floor_area_sqm','resale_price','lease_commence_year','remaining_lease_years']:
    plot(house_new_data ,i)

# %%
# 'floor_area_sqm','resale_price' this two feature are skewd in data handling log method 


house_new_data['floor_area_sqm'] = np.log(house_new_data['floor_area_sqm'])
house_new_data['resale_price'] = np.log(house_new_data['resale_price'])
house_new_data
# Out:
#         town  flat_type block       street_name  storey_range  floor_area_sqm  \
# 0          0          2   170  ANG MO KIO AVE 4             4        4.234107
# 1          0          2   174  ANG MO KIO AVE 4             2        4.110874
# 2          0          2   216  ANG MO KIO AVE 1             4        4.290459
# 3          0          2   215  ANG MO KIO AVE 1             4        4.290459
# 4          0          2   218  ANG MO KIO AVE 1             4        4.204693
# ...      ...        ...   ...               ...           ...             ...
# 932367    26          4   816      YISHUN ST 81             5        4.804021
# 932368    26          5   325       YISHUN CTRL             5        4.983607
# 932369    26          5   618    YISHUN RING RD             4        5.099866
# 932370    26          5   277      YISHUN ST 22             4        5.023881
# 932371    26          5   277      YISHUN ST 22             2        4.983607
#
#         flat_model  resale_price  year  month_of_year  lease_commence_year  \
# 0                9     11.898188  2000              1                 1986
# 1                9     11.877569  2000              1                 1986
# 2               21     11.976659  2000              1                 1976
# 3               21     12.025749  2000              1                 1976
# 4               21     12.001505  2000              1                 1976
# ...            ...           ...   ...            ...                  ...
# 932367           9     13.270783  2014             12                 1988
# 932368          15     13.199324  2014             12                 1988
# 932369           5     13.511699  2014             12                 1992
# 932370          15     13.291262  2014             12                 1985
# 932371          15     13.208541  2014             12                 1985
#
#         remaining_lease_years  remaining_lease_months
# 0                   74.007684                6.535533
# 1                   74.007684                6.535533
# 2                   74.007684                6.535533
# 3                   74.007684                6.535533
# 4                   74.007684                6.535533
# ...                       ...                     ...
# 932367              74.007684                6.535533
# 932368              74.007684                6.535533
# 932369              74.007684                6.535533
# 932370              74.007684                6.535533
# 932371              74.007684                6.535533
#
# [932372 rows x 13 columns]

# %%
for i in ['floor_area_sqm','resale_price']:
    plot(house_new_data,i)

# %% [markdown]
# Treat Outliers using IQR

# %%
#using the IQR & Clips  method removing the outliars :
# formula IQR = Q3_Q1
def outlier(house_new_data ,column):
    IQR = house_new_data[column].quantile(0.75)-house_new_data[column].quantile(0.25)
    upper_value = house_new_data[column].quantile(0.75)+1.5*IQR
    lower_value = house_new_data[column].quantile(0.25)-1.5*IQR
    
    house_new_data[column] =     house_new_data[column].clip(upper_value,lower_value)

outlier(house_new_data, 'floor_area_sqm')
outlier(house_new_data, 'resale_price')
house_new_data1 = house_new_data.copy()

# %%
house_new_data1
# Out:
#         town  flat_type block       street_name  storey_range  floor_area_sqm  \
# 0          0          2   170  ANG MO KIO AVE 4             4        4.234107
# 1          0          2   174  ANG MO KIO AVE 4             2        4.110874
# 2          0          2   216  ANG MO KIO AVE 1             4        4.290459
# 3          0          2   215  ANG MO KIO AVE 1             4        4.290459
# 4          0          2   218  ANG MO KIO AVE 1             4        4.204693
# ...      ...        ...   ...               ...           ...             ...
# 932367    26          4   816      YISHUN ST 81             5        4.804021
# 932368    26          5   325       YISHUN CTRL             5        4.983607
# 932369    26          5   618    YISHUN RING RD             4        5.099866
# 932370    26          5   277      YISHUN ST 22             4        5.023881
# 932371    26          5   277      YISHUN ST 22             2        4.983607
#
#         flat_model  resale_price  year  month_of_year  lease_commence_year  \
# 0                9     11.898188  2000              1                 1986
# 1                9     11.877569  2000              1                 1986
# 2               21     11.976659  2000              1                 1976
# 3               21     12.025749  2000              1                 1976
# 4               21     12.001505  2000              1                 1976
# ...            ...           ...   ...            ...                  ...
# 932367           9     13.270783  2014             12                 1988
# 932368          15     13.199324  2014             12                 1988
# 932369           5     13.511699  2014             12                 1992
# 932370          15     13.291262  2014             12                 1985
# 932371          15     13.208541  2014             12                 1985
#
#         remaining_lease_years  remaining_lease_months
# 0                   74.007684                6.535533
# 1                   74.007684                6.535533
# 2                   74.007684                6.535533
# 3                   74.007684                6.535533
# 4                   74.007684                6.535533
# ...                       ...                     ...
# 932367              74.007684                6.535533
# 932368              74.007684                6.535533
# 932369              74.007684                6.535533
# 932370              74.007684                6.535533
# 932371              74.007684                6.535533
#
# [932372 rows x 13 columns]

# %%
# after IQR using checking the skewness
for i in ['floor_area_sqm','resale_price']:
    plot(house_new_data1,i)

# %%
# Setting the figure size
plt.figure(figsize=(15, 6))

# Creating the bar plot with custom colors and assigning `hue`
sns.barplot(y='flat_model', x='resale_price', data=house, hue='flat_model', palette=sns.color_palette("husl", 34), legend=False)

# Adding labels and title
plt.xlabel('Resale Price')
plt.ylabel('Flat Model')
plt.title('Resale Price by Flat Model')

# Displaying the plot
plt.show()

# %%
# Setting the figure size
plt.figure(figsize=(15, 6))

# Creating the bar plot with a custom color palette
sns.barplot(y='town', x='resale_price', data=house,hue='town', palette="magma")

# Adding labels and title
plt.xlabel('Resale Price')
plt.ylabel('Town')
plt.title('Resale Price by Town')

# Displaying the plot
plt.show()

# %% [markdown]
# Basic EDA

# %%
plt.figure(figsize= (15,6))
sns.barplot(y = 'flat_type', x= 'resale_price',data = house,hue='flat_type',palette="viridis" )
# Out:
# <Axes: xlabel='resale_price', ylabel='flat_type'>

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x = 'resale_price' ,y = 'floor_area_sqm',data = house,hue = 'resale_price',palette = 'magma')

# Adding labels and title
plt.xlabel('Resale Price')
plt.ylabel('Floor Area (sqm)')
plt.title('Resale Price vs. Floor Area')

# Displaying the plot
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'lease_commence_year' , y = 'resale_price', data = house_new_data)
# Out:
# <Axes: xlabel='lease_commence_year', ylabel='resale_price'>

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'year', y = 'resale_price', data = house_new_data,color = 'green')
# Out:
# <Axes: xlabel='year', ylabel='resale_price'>

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'remaining_lease_years' , y = 'resale_price', data = house_new_data, color = 'red')
# Out:
# <Axes: xlabel='remaining_lease_years', ylabel='resale_price'>

# %%
# dropping the irrelvent feature 
house_new_data1.drop(columns=['block','street_name'],inplace = True)
house_new_data1
# Out:
#         town  flat_type  storey_range  floor_area_sqm  flat_model  \
# 0          0          2             4        4.234107           9
# 1          0          2             2        4.110874           9
# 2          0          2             4        4.290459          21
# 3          0          2             4        4.290459          21
# 4          0          2             4        4.204693          21
# ...      ...        ...           ...             ...         ...
# 932367    26          4             5        4.804021           9
# 932368    26          5             5        4.983607          15
# 932369    26          5             4        5.099866           5
# 932370    26          5             4        5.023881          15
# 932371    26          5             2        4.983607          15
#
#         resale_price  year  month_of_year  lease_commence_year  \
# 0          11.898188  2000              1                 1986
# 1          11.877569  2000              1                 1986
# 2          11.976659  2000              1                 1976
# 3          12.025749  2000              1                 1976
# 4          12.001505  2000              1                 1976
# ...              ...   ...            ...                  ...
# 932367     13.270783  2014             12                 1988
# 932368     13.199324  2014             12                 1988
# 932369     13.511699  2014             12                 1992
# 932370     13.291262  2014             12                 1985
# 932371     13.208541  2014             12                 1985
#
#         remaining_lease_years  remaining_lease_months
# 0                   74.007684                6.535533
# 1                   74.007684                6.535533
# 2                   74.007684                6.535533
# 3                   74.007684                6.535533
# 4                   74.007684                6.535533
# ...                       ...                     ...
# 932367              74.007684                6.535533
# 932368              74.007684                6.535533
# 932369              74.007684                6.535533
# 932370              74.007684                6.535533
# 932371              74.007684                6.535533
#
# [932372 rows x 11 columns]

# %%
house_new_data1
# Out:
#         town  flat_type  storey_range  floor_area_sqm  flat_model  \
# 0          0          2             4        4.234107           9
# 1          0          2             2        4.110874           9
# 2          0          2             4        4.290459          21
# 3          0          2             4        4.290459          21
# 4          0          2             4        4.204693          21
# ...      ...        ...           ...             ...         ...
# 932367    26          4             5        4.804021           9
# 932368    26          5             5        4.983607          15
# 932369    26          5             4        5.099866           5
# 932370    26          5             4        5.023881          15
# 932371    26          5             2        4.983607          15
#
#         resale_price  year  month_of_year  lease_commence_year  \
# 0          11.898188  2000              1                 1986
# 1          11.877569  2000              1                 1986
# 2          11.976659  2000              1                 1976
# 3          12.025749  2000              1                 1976
# 4          12.001505  2000              1                 1976
# ...              ...   ...            ...                  ...
# 932367     13.270783  2014             12                 1988
# 932368     13.199324  2014             12                 1988
# 932369     13.511699  2014             12                 1992
# 932370     13.291262  2014             12                 1985
# 932371     13.208541  2014             12                 1985
#
#         remaining_lease_years  remaining_lease_months
# 0                   74.007684                6.535533
# 1                   74.007684                6.535533
# 2                   74.007684                6.535533
# 3                   74.007684                6.535533
# 4                   74.007684                6.535533
# ...                       ...                     ...
# 932367              74.007684                6.535533
# 932368              74.007684                6.535533
# 932369              74.007684                6.535533
# 932370              74.007684                6.535533
# 932371              74.007684                6.535533
#
# [932372 rows x 11 columns]

# %%
house_new_data1.dtypes
# Out:
# town                        int64
# flat_type                   int64
# storey_range                int64
# floor_area_sqm            float64
# flat_model                  int64
# resale_price              float64
# year                        int32
# month_of_year               int32
# lease_commence_year         int32
# remaining_lease_years     float64
# remaining_lease_months    float64
# dtype: object

# %%
house_data_final = house_new_data1.corr()
house_data_final
# Out:
#                             town  flat_type  storey_range  floor_area_sqm  \
# town                    1.000000   0.136932     -0.047725        0.136032
# flat_type               0.136932   1.000000      0.074262        0.940973
# storey_range           -0.047725   0.074262      1.000000        0.049407
# floor_area_sqm          0.136032   0.940973      0.049407        1.000000
# flat_model             -0.102321  -0.359762     -0.068188       -0.362585
# resale_price            0.084071   0.599953      0.187852        0.596736
# year                    0.072175   0.100700      0.105590        0.074820
# month_of_year           0.003049   0.003470     -0.002680        0.003104
# lease_commence_year     0.213031   0.404995      0.168424        0.418009
# remaining_lease_years   0.084142   0.072571      0.134553        0.060237
# remaining_lease_months  0.000794  -0.001123     -0.000254       -0.001723
#
#                         flat_model  resale_price      year  month_of_year  \
# town                     -0.102321      0.084071  0.072175       0.003049
# flat_type                -0.359762      0.599953  0.100700       0.003470
# storey_range             -0.068188      0.187852  0.105590      -0.002680
# floor_area_sqm           -0.362585      0.596736  0.074820       0.003104
# flat_model                1.000000     -0.180198  0.062735      -0.004946
# resale_price             -0.180198      1.000000  0.691674       0.009898
# year                      0.062735      0.691674  1.000000      -0.025411
# month_of_year            -0.004946      0.009898 -0.025411       1.000000
# lease_commence_year      -0.117332      0.535795  0.433539       0.003601
# remaining_lease_years    -0.030490      0.085302 -0.001888      -0.003374
# remaining_lease_months    0.000525      0.001395  0.000751       0.007474
#
#                         lease_commence_year  remaining_lease_years  \
# town                               0.213031               0.084142
# flat_type                          0.404995               0.072571
# storey_range                       0.168424               0.134553
# floor_area_sqm                     0.418009               0.060237
# flat_model                        -0.117332              -0.030490
# resale_price                       0.535795               0.085302
# year                               0.433539              -0.001888
# month_of_year                      0.003601              -0.003374
# lease_commence_year                1.000000               0.528995
# remaining_lease_years              0.528995               1.000000
# remaining_lease_months             0.009838              -0.000995
#
#                         remaining_lease_months
# town                                  0.000794
# flat_type                            -0.001123
# storey_range                         -0.000254
# floor_area_sqm                       -0.001723
# flat_model                            0.000525
# resale_price                          0.001395
# year                                  0.000751
# month_of_year                         0.007474
# lease_commence_year                   0.009838
# remaining_lease_years                -0.000995
# remaining_lease_months                1.000000

# %%
# Need to verify any columns are highly correlated using Heatmap

import matplotlib.colors as mcolors
# Define a custom color map
custom_cmap = mcolors.ListedColormap(['#d6c1c9', '#d1b40f', '#c248ff', '#ff4500'])
plt.figure(figsize=(15,6))
sns.heatmap(house_data_final,annot = True,cmap=custom_cmap, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# Model Buliding

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model   import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
import pickle

# %%
house_new_data1.columns
# Out:
# Index(['town', 'flat_type', 'storey_range', 'floor_area_sqm', 'flat_model',
#        'resale_price', 'year', 'month_of_year', 'lease_commence_year',
#        'remaining_lease_years', 'remaining_lease_months'],
#       dtype='object')

# %%
x = house_new_data1[['town', 'flat_type', 'storey_range', 'floor_area_sqm', 'flat_model',
        'year', 'month_of_year', 'lease_commence_year',
       'remaining_lease_years', 'remaining_lease_months']]
y = house_new_data1[['resale_price']]

# %%
#standardize the features of a dataset
encoder = StandardScaler()

encoder.fit_transform(x)
# Out:
# array([[-1.55296831e+00, -1.06857691e+00,  2.20020961e-01, ...,
#         -2.17519648e-01,  9.96448462e-15, -8.28132164e-15],
#        [-1.55296831e+00, -1.06857691e+00, -5.29663415e-01, ...,
#         -2.17519648e-01,  9.96448462e-15, -8.28132164e-15],
#        [-1.55296831e+00, -1.06857691e+00,  2.20020961e-01, ...,
#         -1.15039749e+00,  9.96448462e-15, -8.28132164e-15],
#        ...,
#        [ 1.40367542e+00,  2.09181755e+00,  2.20020961e-01, ...,
#          3.42207059e-01,  9.96448462e-15, -8.28132164e-15],
#        [ 1.40367542e+00,  2.09181755e+00,  2.20020961e-01, ...,
#         -3.10807432e-01,  9.96448462e-15, -8.28132164e-15],
#        [ 1.40367542e+00,  2.09181755e+00, -5.29663415e-01, ...,
#         -3.10807432e-01,  9.96448462e-15, -8.28132164e-15]])

# %%
#check the accuracy of training and testing using metrics RandomForestRegressor


x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

RFR= RandomForestRegressor(n_estimators= 50 ,random_state = 0)

# fitting the model: 

RFR.fit(x_train,y_train)

y_pred_train = RFR.predict(x_train)
y_pred_test = RFR.predict(x_test)

r2_train = r2_score(y_train,y_pred_train)
r2_test = r2_score(y_test,y_pred_test)

r2_train,r2_test
# Out:
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# (0.9959842217238352, 0.981159038578015)

# %%
# we got good accuracy after oversampling
# RandomForestRegressor have good testing accuracy, but in training accuracy is overfitting.

# %%
# GridsearchCV is a cross validation function
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)

param = {'max_depth'        : [20],
              'min_samples_split': [ 5, ],
              'min_samples_leaf' : [ 2, ],
              'max_features'     : ['log2']}
grid_searchcv = GridSearchCV(RandomForestRegressor(),param_grid = param,  cv = 5)
grid_searchcv.fit(x_train, y_train)
# Out:
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [20], 'max_features': ['log2'],
#                          'min_samples_leaf': [2], 'min_samples_split': [5]})

# %%
grid_searchcv.best_score_
# Out:
# np.float64(0.9746495400028442)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

Hyper_model= RandomForestRegressor(max_depth= 20 ,max_features='log2' ,min_samples_leaf=2, min_samples_split=5)

# fitting the model: 

Hyper_model.fit(x_train,y_train)

y_pred_train = Hyper_model.predict(x_train)
y_pred_test = Hyper_model.predict(x_test)

r2_train = r2_score(y_train,y_pred_train)
r2_test = r2_score(y_test,y_pred_test)

r2_train,r2_test
# Out:
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# (0.9812195928948398, 0.9753966748491397)

# %%
# now the training accuracy overfitting reduced. so now model will predict effectively for unseen data

# %%
# predict the selling price with hypertuning parameters and calculate the accuracy using metrics

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)
x_train.shape,x_test.shape

RFR = RandomForestRegressor()

Hyper_model= RandomForestRegressor(max_depth= 20 ,max_features='log2' ,min_samples_leaf=2, min_samples_split=5)

# fitting the model: 

Hyper_model.fit(x_train,y_train)

y_pred_train = Hyper_model.predict(x_train)
y_pred_test = Hyper_model.predict(x_test)                      
print('Mean Squared Error:' ,mean_squared_error(y_test,y_pred_test))
print('Mean Absolute Error:',mean_absolute_error(y_test,y_pred_test))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,y_pred_test)))
print(r2_score(y_test,y_pred_test))
# Out:
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Mean Squared Error: 0.008303490229100853
# Mean Absolute Error: 0.06653564910002749
# Root Mean Squared Error: 0.09112348889886104
# 0.9752751330320829

# %%
# manually passed the user input and predict the selling price

user_data = np.array([[0,1,3,3.785069,5,2017,1,1979,61.000000,4.000000]])
y_prediction = Hyper_model.predict(user_data)
y_prediction[0]
# Out:
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# np.float64(12.318913738045124)

# %%
user_data = np.array([[4,3,2,4.785069,4,2023,3,1989,69.000000,4.000000]])

y_prediction = Hyper_model.predict(user_data)
y_prediction[0]
# Out:
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# np.float64(13.438789476516915)

# %%
# using Inverse Log Transformation to convert the value to original re sale price of the data (exp)
np.exp(y_prediction[0])
# Out:
# np.float64(686107.415297677)

# %%
import pickle

# %%
# save the regression model by using pickle

with open("B:\Project\.venv\house_price_model.pkl", 'wb') as f:
    pickle.dump(Hyper_model, f)

# %%
# load the model
with open("B:\Project\.venv\house_price_model.pkl", 'rb') as f:
    model = pickle.load(f)

user_data = np.array([[4, 3, 2, 4.785069, 4, 2023, 3, 1989, 69.000000, 4.000000]])
prediction = model.predict(user_data)
predicted_price = prediction[0]
predicted_price
np.exp(predicted_price)
# Out:
# b:\Project\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# np.float64(686107.415297677)
